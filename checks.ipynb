# %%
import tensorflow as tf
import tensorflow_federated as tff
import tensorflow_privacy as tfp

print(f"✅ TFF Version: {tff.__version__}")
print(f"✅ TF Privacy Version: {tfp.__version__}")

# A quick TFF execution test
@tff.federated_computation
def hello_mpp():
    return "Environment Stable for Thesis Research"

print(hello_mpp())

# %%
import tensorflow as tf
import tensorflow_federated as tff
import tensorflow_privacy as tfp
import pandas as pd
import os

print("✅ TFF Version:", tff.__version__)
print("✅ TF Privacy Version:", tfp.__version__)

# Verify your data folder is visible
if os.path.exists('data'):
    print("✅ 'data' folder found.")
    print("Files available:", os.listdir('data'))
else:
    print("❌ 'data' folder not found. Check your Docker volume mount.")

# %%
print("Hello world"
